# %% [markdown]
# <a href="https://colab.research.google.com/github/rosey321-code/rosey321-code/blob/main/Snippets_Importing_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing a library that is not in Colaboratory
#
# To import a library that's not in Colaboratory by default, you can use `!pip install` or `!apt-get install`.

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %% [markdown]
# # Install 7zip reader [libarchive](https://pypi.python.org/pypi/libarchive)

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get update -qq && apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive

# %% [markdown]
# # Install GraphViz & [PyDot](https://pypi.python.org/pypi/pydot)

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %% [markdown]
# # Install [cartopy](http://scitools.org.uk/cartopy/docs/latest/)

# %%
# !pip install cartopy
import cartopy

# %%
# !pip install PyQt6
import sys
from PyQt6.QtWidgets import QApplication, QMainWindow, QVBoxLayout, QWidget
from PyQt6.QtCore import Qt

class ModernCodexUI(QMainWindow):
    def __init__(self):
        super().__init__()

        self.setWindowTitle("Human-Link OS")
        self.setGeometry(100, 100, 800, 600)

        self.layout = QVBoxLayout()
        self.widget = QWidget()
        self.widget.setLayout(self.layout)
        self.setCentralWidget(self.widget)

        self.show()

if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = ModernCodexUI()
    sys.exit(app.exec())

# %%
print()

# %%
import pandas as pd
import json

# Maan lein aapka data 'results' variable mein hai
df = pd.DataFrame(results)
display(df) # Ye aapko ek sundar table bana kar de dega
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24291/347862303.py in <cell line: 0>()
#       3
#       4 # Maan lein aapka data 'results' variable mein hai
# ----> 5 df = pd.DataFrame(results)
#       6 display(df) # Ye aapko ek sundar table bana kar de dega
#
# NameError: name 'results' is not defined
